# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

pic=Image.open('D://WebCamMotionDetector//images//nikhil.jpeg')
type(pic)

# %%
pic_array=np.asarray(pic)
type(pic_array)
print(pic_array)
# Out:
# [[[139 127 113]
#   [139 127 113]
#   [139 127 113]
#   ...
#   [196 187 182]
#   [196 187 182]
#   [197 188 183]]
#
#  [[139 127 113]
#   [139 127 113]
#   [139 127 113]
#   ...
#   [196 187 182]
#   [197 188 183]
#   [197 188 183]]
#
#  [[139 127 113]
#   [139 127 113]
#   [139 127 113]
#   ...
#   [196 187 182]
#   [197 188 183]
#   [198 189 184]]
#
#  ...
#
#  [[219 218 226]
#   [219 218 226]
#   [220 219 227]
#   ...
#   [239 233 235]
#   [239 233 235]
#   [239 233 235]]
#
#  [[219 218 226]
#   [219 218 226]
#   [220 219 227]
#   ...
#   [239 233 235]
#   [239 233 235]
#   [239 233 235]]
#
#  [[219 218 226]
#   [219 218 226]
#   [220 219 227]
#   ...
#   [239 233 235]
#   [239 233 235]
#   [239 233 235]]]

# %%
pic_array.shape
# Out:
# (1280, 1031, 3)

# %%
plt.imshow(pic_array)

# %%
pic_red=pic_array.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1280, 1031, 3)

# %%
#rgb 

plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1])

# %%
pic_red[:,:,1]=0
plt.imshow(pic_red)
